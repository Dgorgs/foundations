# %% [markdown]
# # Homework 14 Part 1

# %% [markdown]
# ## Import

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
# %matplotlib inline
from shapely.geometry import Point 
from shapely.geometry import Polygon
from matplotlib.colors import ListedColormap

# %% [markdown]
# ## Opening datasets

# %%
powerplants = pd.read_csv("/Users/daniela/Desktop/Ledeprogram/Foundation_Soma/14-homework-powerplants/powerplants.csv")
powerplants.head()
# Out:
#    Plant_Code          Plant_Name        Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam  Alabama Power Co         195
# 1           3               Barry  Alabama Power Co         195
# 2           4  Walter Bouldin Dam  Alabama Power Co         195
# 3           7             Gadsden  Alabama Power Co         195
# 4           8              Gorgas  Alabama Power Co         195
#
#          sector_nam       City      County    Zip            Street_Add  \
# 0  Electric Utility  Northport  Tuscaloosa  35476    19001 Lock 17 Road
# 1  Electric Utility      Bucks      Mobile  36512      North Highway 43
# 2  Electric Utility   Wetumpka      Elmore  36092  750 Bouldin Dam Road
# 3  Electric Utility    Gadsden      Etowah  35903     1000 Goodyear Ave
# 4  Electric Utility    Parrish      Walker  35580       460 Gorgas Road
#
#       PrimSource    ...      Solar_MW  Wind_MW  Geo_MW  Other_MW  \
# 0  hydroelectric    ...           0.0      0.0     NaN       NaN
# ...

# %%
usa = gpd.read_file("/Users/daniela/Desktop/Ledeprogram/Foundation_Soma/14-homework-powerplants/cb_2016_us_state_500k/cb_2016_us_state_500k.shp")

# %%
usa
# Out:
#        AFFGEOID          ALAND        AWATER GEOID LSAD  \
# 0   0400000US01   131173688951    4593686489    01   00
# 1   0400000US02  1477946266785  245390495931    02   00
# 2   0400000US04   294198560125    1027346486    04   00
# 3   0400000US05   134771517596    2960191698    05   00
# 4   0400000US06   403501101370   20466718403    06   00
# 5   0400000US08   268429343790    1175112870    08   00
# 6   0400000US09    12542638347    1815476291    09   00
# 7   0400000US10     5047194742    1398720828    10   00
# 8   0400000US11      158364992      18633403    11   00
# 9   0400000US13   149169848456    4741100880    13   00
# 10  0400000US15    16634100855   11777698394    15   00
# 11  0400000US16   214042908012    2398669593    16   00
# 12  0400000US17   143788697679    6206693598    17   00
# 13  0400000US18    92790545247    1536767065    18   00
# 14  0400000US19   144667643793    1077808017    19   00
# 15  0400000US20   211753253104    1346235678    20   00
# ...

# %%
usa.plot(color='lightgrey', linewidth=0.25, edgecolor='white', figsize=(20,20))

# %%
usa = gpd.read_file("/Users/daniela/Desktop/Ledeprogram/Foundation_Soma/14-homework-powerplants/cb_2016_us_state_500k/cb_2016_us_state_500k.shp")
bounds_usa = [
            [
              -130.4296875,
              49.38237278700955
            ],
            [
              -125.5078125,
              33.284619968887675
            ],
            [
              -96.85546875,
              24.367113562651262
            ],
            [
              -80.5078125,
              24.367113562651262
            ],
            [
              -58.00781249999999,
              47.040182144806664
            ],
            [
              -85.78125,
              49.724479188712984
            ],
            [
              -130.4296875,
              49.38237278700955
            ]
]
    
    
usa_box = Polygon(bounds_usa)
usa.crs = {'init': 'epsg:5070'}
usa = usa[usa.within(usa_box)]
usa.head(10)
# Out:
#        AFFGEOID         ALAND       AWATER GEOID LSAD                  NAME  \
# 0   0400000US01  131173688951   4593686489    01   00               Alabama
# 2   0400000US04  294198560125   1027346486    04   00               Arizona
# 3   0400000US05  134771517596   2960191698    05   00              Arkansas
# 4   0400000US06  403501101370  20466718403    06   00            California
# 5   0400000US08  268429343790   1175112870    08   00              Colorado
# 6   0400000US09   12542638347   1815476291    09   00           Connecticut
# 7   0400000US10    5047194742   1398720828    10   00              Delaware
# 8   0400000US11     158364992     18633403    11   00  District of Columbia
# 9   0400000US13  149169848456   4741100880    13   00               Georgia
# 11  0400000US16  214042908012   2398669593    16   00                 Idaho
#
#    STATEFP   STATENS STUSPS                                           geometry
# ...

# %%
#points = powerplants.apply(lambda z: Point(z.Longitude, z.Latitude), axis=1)
#powerplants = gpd.GeoDataFrame(powerplants, geometry=points)
#powerplants.crs = {'init': 'epsg:4326'}
#powerplants = powerplants[powerplants.within(usa_box)]
#powerplants.head(2)

# %%
points = powerplants.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
powerplants = gpd.GeoDataFrame(powerplants, geometry=points)
powerplants.crs = {'init': 'epsg:4326'}
powerplants = powerplants[powerplants.within(usa_box)]
powerplants.head(2)
# Out:
#    Plant_Code    Plant_Name        Utility_Na  Utility_ID        sector_nam  \
# 0           2  Bankhead Dam  Alabama Power Co         195  Electric Utility
# 1           3         Barry  Alabama Power Co         195  Electric Utility
#
#         City      County    Zip          Street_Add     PrimSource  \
# 0  Northport  Tuscaloosa  35476  19001 Lock 17 Road  hydroelectric
# 1      Bucks      Mobile  36512    North Highway 43           coal
#
#                    ...                   Wind_MW  Geo_MW  Other_MW  \
# 0                  ...                       0.0     NaN       NaN
# 1                  ...                       0.0     NaN       NaN
#
#                                 source_des  \
# 0                    Hydroelectric = 56 MW
# 1  Coal = 1088.5 MW, Natural Gas = 1072 MW
#
#                                            tech_desc  \
# 0                         Conventional Hydroelectric
# 1  Conventional Steam Coal; Natural Gas Fired Com...
#
# ...

# %%
from shapely.geometry import Polygon
us_states.to_crs({'init': 'epsg:4326'}).intersects(powerplants).head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# ## Map of power plants in the US, color coded by type

# %%
ax = us_states.plot(figsize=(20,20), color='grey', linewidth=0.25, edgecolor='white')
powerplants.plot(ax=ax, markeredgewidth=0, markersize=3, legend=True)
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %% [markdown]
# ## Make a map of air quality stations, color coded by average air quality

# %%
airquality = pd.read_csv("/Users/daniela/Desktop/Ledeprogram/Foundation_Soma/14-homework-powerplants/pm25_annual_fixed.csv")
airquality.head(5)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1            3        10           88101    1  30.497478
# 1           1           27         1           88101    1  33.284928
# 2           1           33      1002           88101    1  34.762619
# 3           1           49      1003           88101    1  34.288567
# 4           1           55        10           88101    1  33.991494
#
#    Longitude  Datum            Parameter Name Sample Duration  \
# 0 -87.880258  NAD83  PM2.5 - Local Conditions         24 HOUR
# 1 -85.803608  NAD83  PM2.5 - Local Conditions         24 HOUR
# 2 -87.638097  NAD83  PM2.5 - Local Conditions         24 HOUR
# 3 -85.969858  NAD83  PM2.5 - Local Conditions         24 HOUR
# 4 -85.992647  NAD83  PM2.5 - Local Conditions         24 HOUR
#
#           ...          75th Percentile 50th Percentile 10th Percentile  \
# 0         ...                      8.0             5.7             3.8
# ...

# %%
points = airquality.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
airquality = gpd.GeoDataFrame(airquality, geometry=points)
airquality.crs = {'init': 'epsg:4326'}

# %%
ax = us_states.plot(figsize=(25,25), color='grey', linewidth=0.25, edgecolor='white')
airquality.plot(column= 'Arithmetic Mean', cmap='inferno', ax=ax, markeredgewidth=0, markersize=3)
ax.axis('off')
# Out:
# (-163.98705724999999,
#  -62.329077749999996,
#  17.922097100000002,
#  50.882560900000001)

# %% [markdown]
# ## Map the power plants owned by the top 5 most common energy companies as red. Map the rest of the plants as dark grey.

# %%
powerplants['Utility_Na'].value_counts().head()
# Out:
# Pacific Gas & Electric Co        82
# Erie Boulevard Hydropower LP     71
# Sustainable Power Group, LLC     63
# Southern California Edison Co    62
# PacifiCorp                       59
# Name: Utility_Na, dtype: int64

# %%
Top_5 = powerplants[powerplants.Utility_Na.isin(['Pacific Gas & Electric Co', 'Erie Boulevard Hydropower LP', 'Sustainable Power Group, LLC', 'Southern California Edison Co', 'PacifiCorp'])]

# %%
Top_5.plot(color='red')

# %%
Rest = powerplants[~powerplants.Utility_Na.isin(['Pacific Gas & Electric Co', 'Erie Boulevard Hydropower LP', 'Sustainable Power Group, LLC', 'Southern California Edison Co', 'PacifiCorp'])]

# %%
Rest.plot(color='grey')

# %%
ax = usa.plot(figsize=(20,20), color='green', linewidth=0.25, edgecolor='white')
Rest.plot(color='grey', ax=ax, markeredgewidth=0, markersize=3)
Top_5.plot(color='red', ax=ax, markeredgewidth=0, markersize=3)
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %% [markdown]
# ## Map all of the nuclear power plants in red, with the rest of the plants as dark grey

# %%
powerplants.columns
# Out:
# Index(['Plant_Code', 'Plant_Name', 'Utility_Na', 'Utility_ID', 'sector_nam',
#        'City', 'County', 'Zip', 'Street_Add', 'PrimSource', 'Total_MW',
#        'Coal_MW', 'NG_MW', 'Crude_MW', 'Bio_MW', 'Hydro_MW', 'HydroPS_MW',
#        'Nuclear_MW', 'Solar_MW', 'Wind_MW', 'Geo_MW', 'Other_MW', 'source_des',
#        'tech_desc', 'Source', 'Period', 'Latitude', 'Longitude', 'geometry'],
#       dtype='object')

# %%
powerplants['Nuclear_MW'].value_counts().head()
# Out:
# 0.0       7357
# 1808.0       1
# 601.4        1
# 2087.8       1
# 2328.2       1
# Name: Nuclear_MW, dtype: int64

# %%
Nuclear_plants = powerplants[powerplants.PrimSource.isin(['nuclear'])]

# %%
Nuclear_plants.plot(color='red')

# %%
Non_Nuclear_plants = powerplants[~powerplants.PrimSource.isin(['nuclear'])]

# %%
Non_Nuclear_plants.plot(color='grey')

# %%
ax = usa.plot(figsize=(20,20), color='green', linewidth=0.25, edgecolor='white')
Non_Nuclear_plants.plot(color='grey', ax=ax, markeredgewidth=0, markersize=3)
Nuclear_plants.plot(color='red', ax=ax, markeredgewidth=0, markersize=3)
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)

# %% [markdown]
# # Map power plants that produce energy through both natural gas and oil

# %%
gasandoil = powerplants[powerplants.PrimSource.isin(['natural gas', 'oil'])]

# %%
Nogasoil = powerplants[~powerplants.PrimSource.isin(['natural gas', 'oil'])]

# %%
ax = usa.plot(figsize=(20,20), color='green', linewidth=0.25, edgecolor='white')
Nogasoil.plot(color='grey', ax=ax, markeredgewidth=0, markersize=3)
gasandoil.plot(color='red', ax=ax, markeredgewidth=0, markersize=3)
ax.axis('off')
# Out:
# (-127.65372665000001,
#  -64.059236349999992,
#  23.280032899999998,
#  50.627421099999999)
