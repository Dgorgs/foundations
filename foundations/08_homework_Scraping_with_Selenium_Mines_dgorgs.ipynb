# %% [markdown]
# # Scraping many pages + Using Selenium
#
# ## The pages we'll be looking at
#
# If I wanted to read specific information about a specfic mine, it takes a few steps. **Do these steps with your browser before you try any programming.**
#
# 1. Visit the [Mine Data Retrieval System](https://arlweb.msha.gov/drs/drshome.htm)
# 2. Scroll down to **Mine Identification Number (ID) Search**
# 3. Type in a mine ID number, such as `3503598`, click **Search**
# 4. I'm on a page! It lists the MINE NAME and MINE OWNER.
#
# After searching for and finding a mine, I can use this page to **find reports about this mine**. Some of the reports are on accidents, violations, inspections, health samples and more. To get those reports:
#
# 1. Search for a mine (if you haven't already)
# 2. Scroll down and change **Beginning Date** to `1/1/1995` (violation reports begin in 1995, accidents begin in 1983)
# 3. Select the report type of `Violations`
# 4. Click **Get Report**
# 5. I'm on a page! It lists ALL OF THE MINE'S VIOLATIONS.
#
# By changing the report type you're searching for you can find all sorts of different data.

# %% [markdown]
# # Researching mine information

# %% [markdown]
# ## Preparation
#
# ### When you search for information on a specific mine, what URL should Selenium visit first?
#
# - *TIP: the answer is NOT `https://arlweb.msha.gov/drs/ASP/BasicMineInfonew.asp`*

# %%
# https://arlweb.msha.gov/drs/drshome.htm

# %% [markdown]
# ### How can you identify the text field we're going to type the Mine ID into?
#
# Selenium can find elements by:
#
# - name
# - Class
# - ID
# - CSS selector (**ASK ME WHAT THIS IS** if you don't know)
# - XPath (**ASK ME WHAT THIS IS** because you definitely don't know)
# - Link text
# - Partial link text
#
# So in other words, what's unique about this element?

# %%
# //*[@id="inputdrs"]

# %% [markdown]
# ### How can you identify the search button we're going to click, or the form we're going to submit?
#
# Selenium can submit forms by either
#
# - Selecting the form and using `.submit()`, or
# - Selecting the button and using `.click()`
#
# You only need to be able to get **one, not both.**

# %%
# The button's xpath is:
#//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input

# %% [markdown]
# ### Use Selenium to search using the mine ID `3901432`. Get me the operator's name by scraping.
#
# - *TIP: You can find elements/text using Selenium, or use BeautifulSoup with `doc = BeautifulSoup(driver.page_source)`*

# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://arlweb.msha.gov/drs/drshome.htm")

# %%
input_field = driver.find_element_by_name("MineId")
input_field
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="d28ce10f3c02c47146758e12eaf484be", element="0.6019398950913999-1")>

# %%
input_field.send_keys("3901432")

# %%
search_button = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input')
search_button.click()

# %%
name_tag = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[1]/tbody/tr[3]/td[2]/font/b')

# %%
name_tag.text
# Out:
# 'Krueger Brothers Gravel & Dirt'

# %% [markdown]
# # Using .apply to find data about SEVERAL mines
#
# The file `mines-subset.csv` has a list of mine IDs. We're going to scrape the operator's name for each of those mines.
#
# ### Open up `mines-subset.csv` and save it into a dataframe

# %%
import pandas as pd
df = pd.read_csv("mines-subset.csv", dtype={'id': 'str'})
df.head()
# Out:
#         id
# 0  4104757
# 1  0801306
# 2  3609931

# %% [markdown]
# ### Open up `mines-subset.csv` in a text editor, then look at your dataframe. Is something different about them?

# %%
# !cat mines-subset.csv
# Out:
# id
# 4104757
# 0801306
# 3609931

# %% [markdown]
# ### Scrape the operator's name for each of those mines and print it
#
# - *TIP: use .apply and a function*
# - *TIP: If you need help with .apply, look at the "Using apply in pandas" notebook *

# %% [raw]
# driver = webdriver.Chrome()

# %%
def scrape_name(row):
    driver.get("https://arlweb.msha.gov/drs/drshome.htm")
    input_field = driver.find_element_by_name("MineId")
    input_field.send_keys(row['id'])
    search_button = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input')
    search_button.click()
    name_tag = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[1]/tbody/tr[3]/td[2]/font/b')
    return name_tag.text
    #print(name_tag.text)
    #print(row['id'])
    #print("-----")
    #driver = webdriver.Chrome()
df['name'] = df.apply(scrape_name, axis=1)
#driver.close()

# %%
df.head()
# Out:
#         id                      name
# 0  4104757                Dirt Works
# 1  0801306  Holley Dirt Company, Inc
# 2  3609931            M.R. Dirt Inc.

# %% [markdown]
# ### Scrape the operator's name and save it into a new column
#
# - *TIP: Use .apply and a function*
# - *TIP: Remember to use `return`*

# %%
df['name'] = df.apply(scrape_name, axis=1)

# %%
df.head()
# Out:
#         id                      name
# 0  4104757                Dirt Works
# 1  0801306  Holley Dirt Company, Inc
# 2  3609931            M.R. Dirt Inc.

# %% [markdown]
# # Researching mine violations
#
# Read the very top again to remember how to find mine violations

# %% [markdown]
# ### When you search for a mine's violations, what URL is Selenium going to start on?
#
# - *TIP: `requests` can send form data to load in the middle of a bunch of steps, but Selenium has to start at the beginning

# %%
# url = https://arlweb.msha.gov/drs/drshome.htm

# %% [markdown]
# ### When you're searching for violations from the Mine Information page, how are you going to identify the "Beginning Date" field?

# %%
# //*[@id="content"]/form[1]/table[2]/tbody/tr[2]/td/font/input[1]

# %% [markdown]
# ### When you're searching for violations from the Mine Information page, how are you going to identify the "Violations" button?

# %%
# //*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input

# %% [markdown]
# ### When you're searching for violations from the Mine Information page, how are you going to identify the form or the button to click to get a list of the violations?

# %%
# //*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input

# %% [markdown]
# ### Using the mine ID `3901432`, scrape all of their violations since 1/1/1995
#
# **Save this into a CSV called `3901432-violations.csv`.** This CSV must include the following fields:
#
# - Citation number
# - Case number
# - Standard violated
# - Link to standard
# - Proposed penalty
# - Amount paid to date
#
# **Tips:**
#
# - *TIP: It's probably worth it to print them all first, then save them to a CSV once you know it's all working.*
# - *TIP: You'll use the parent pattern - get the ROWS first (tr), then loop through and get the TABLE CELLS (td)*

# %%
# get to the main line page
driver.get("https://arlweb.msha.gov/drs/drshome.htm")
input_field = driver.find_element_by_name("MineId")
input_field.send_keys('3901432')
search_button = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input')
search_button.click()

# %%
date_field = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[2]/tbody/tr[2]/td/font/input[1]')
date_field.send_keys("1/1/1995")

# %%
violation_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
violation_button.click()

# %%
reports_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
reports_button.click()

# %%
#Citation number
#Case number
#Standard violated
#Link to standard
#Proposed penalty
#Amount paid to date

# %%
from bs4 import BeautifulSoup

# %%
doc = BeautifulSoup(driver.page_source, 'html.parser')

# %%
violation_rows = doc.find_all('tr', class_='drsviols')
len(violation_rows)
# Out:
# 18

# %%
for violation_row in violation_rows:
    print("I have a violation")
    cells = violation_row.find_all('td')
    print("Citation no", cells[2].text)
    print("Case no", cells[3].text)
    print("Standard violated", cells[10].find('a').text)
    print("Link", cells [10].find('a')['href'])
    print("Proposed penalty", cells[11].text)
    print("Amount paid to date", cells[14].text)
    
    print("I found", len(cells), "td elements")

    print("-----")
# Out:
# I have a violation
# Citation no 8750964
# Case no 000361866
# Standard violated
# 56.18010
# Link http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-18010.pdf
# Proposed penalty 100.00
# Amount paid to date 100.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 6426439
# Case no 000260865
# Standard violated
# 56.4201(a)(2)
# Link http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec56-4201.pdf
# Proposed penalty 100.00
# Amount paid to date 100.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 6426438
# Case no 000260865
# Standard violated
# 56.4101
# Link http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec56-4101.pdf
# Proposed penalty 100.00
# Amount paid to date 100.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 6588189
# Case no 000260865
# Standard violated
# 56.14200
# Link http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec56-14200.pdf
# Proposed penalty 100.00
# Amount paid to date 100.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 6588210
# Case no 000238554
# Standard violated
# 50.30(a)
# Link http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec50-30.pdf
# Proposed penalty 100.00
# Amount paid to date 100.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 6328074
# Case no 000188398
# Standard violated
# 56.11003
# Link http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-11003.pdf
# Proposed penalty 100.00
# Amount paid to date 100.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916117
# Case no 390143205501
# Standard violated
# 56.1000
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-1000.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916122
# Case no 390143205501
# Standard violated
# 56.20008
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-20008.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916121
# Case no 390143205501
# Standard violated
# 56.18002
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-18002.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916116
# Case no 390143205501
# Standard violated
# 50.30
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec50-30.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916115
# Case no 390143205501
# Standard violated
# 41.20
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec41-20.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916124
# Case no 390143205501
# Standard violated
# 56.14132(a)
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-14132.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916118
# Case no 390143205501
# Standard violated
# 56.12028
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-12028.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916120
# Case no 390143205501
# Standard violated
# 56.15001
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-15001.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916126
# Case no 390143205501
# Standard violated
# 56.14100(d)
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-14100.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916119
# Case no 390143205502
# Standard violated
# 56.18010
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-18010.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916123
# Case no 390143205501
# Standard violated
# 56.14132(a)
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-14132.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----
# I have a violation
# Citation no 7916125
# Case no 390143205501
# Standard violated
# 56.4200
# Link http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-4200.pdf
# Proposed penalty 55.00
# Amount paid to date 55.00
# I found 15 td elements
# -----

# %%
#to save to a CSV
# 1. make an emtpy list
# 2. every time through the loop, create a dictionary of your data
# 3. add the dictionary to the list
# 4. when the entire loop is over, convert the list to a dataframe
# 5. save that dataframe

violations = []
for violation_row in violation_rows:
    violation = {}
    cells = violation_row.find_all('td')
    violation['citation'] = cells[2].text.strip()
    violation['case no'] = cells[3].text.strip()
    violation['standard'] = cells[10].find('a').text.strip()
    violation['link'] = cells [10].find('a')['href']
    violation['proposed'] = cells[11].text.strip()
    violation['paid'] = cells[14].text.strip()
    violations.append(violation)

# %%
violations
# Out:
# [{'case no': '000361866',
#   'citation': '8750964',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-vol1/pdf/CFR-2014-title30-vol1-sec56-18010.pdf',
#   'paid': '100.00',
#   'proposed': '100.00',
#   'standard': '56.18010'},
#  {'case no': '000260865',
#   'citation': '6426439',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec56-4201.pdf',
#   'paid': '100.00',
#   'proposed': '100.00',
#   'standard': '56.4201(a)(2)'},
#  {'case no': '000260865',
#   'citation': '6426438',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec56-4101.pdf',
#   'paid': '100.00',
#   'proposed': '100.00',
#   'standard': '56.4101'},
#  {'case no': '000260865',
#   'citation': '6588189',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-vol1/pdf/CFR-2011-title30-vol1-sec56-14200.pdf',
#   'paid': '100.00',
#   'proposed': '100.00',
#   'standard': '56.14200'},
#  {'case no': '000238554',
#   'citation': '6588210',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-vol1/pdf/CFR-2010-title30-vol1-sec50-30.pdf',
#   'paid': '100.00',
#   'proposed': '100.00',
#   'standard': '50.30(a)'},
#  {'case no': '000188398',
#   'citation': '6328074',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-2009-title30-vol1/pdf/CFR-2009-title30-vol1-sec56-11003.pdf',
#   'paid': '100.00',
#   'proposed': '100.00',
#   'standard': '56.11003'},
#  {'case no': '390143205501',
#   'citation': '7916117',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-1000.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.1000'},
#  {'case no': '390143205501',
#   'citation': '7916122',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-20008.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.20008'},
#  {'case no': '390143205501',
#   'citation': '7916121',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-18002.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.18002'},
#  {'case no': '390143205501',
#   'citation': '7916116',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec50-30.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '50.30'},
#  {'case no': '390143205501',
#   'citation': '7916115',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec41-20.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '41.20'},
#  {'case no': '390143205501',
#   'citation': '7916124',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-14132.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.14132(a)'},
#  {'case no': '390143205501',
#   'citation': '7916118',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-12028.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.12028'},
#  {'case no': '390143205501',
#   'citation': '7916120',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-15001.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.15001'},
#  {'case no': '390143205501',
#   'citation': '7916126',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-14100.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.14100(d)'},
#  {'case no': '390143205502',
#   'citation': '7916119',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-18010.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.18010'},
#  {'case no': '390143205501',
#   'citation': '7916123',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-14132.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.14132(a)'},
#  {'case no': '390143205501',
#   'citation': '7916125',
#   'link': 'http://www.gpo.gov/fdsys/pkg/CFR-1998-title30-vol1/pdf/CFR-1998-title30-vol1-sec56-4200.pdf',
#   'paid': '55.00',
#   'proposed': '55.00',
#   'standard': '56.4200'}]

# %%
import pandas as pd
df = pd.DataFrame(violations)
df.head()
# Out:
#      case no citation                                               link  \
# 0  000361866  8750964  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...
# 1  000260865  6426439  http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-...
# 2  000260865  6426438  http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-...
# 3  000260865  6588189  http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-...
# 4  000238554  6588210  http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-...
#
#      paid proposed       standard
# 0  100.00   100.00       56.18010
# 1  100.00   100.00  56.4201(a)(2)
# 2  100.00   100.00        56.4101
# 3  100.00   100.00       56.14200
# 4  100.00   100.00       50.30(a)

# %%
df.to_csv("3901432-violations.csv", index=False)

# %%
df = pd.read_csv("mines-subset.csv", dtype={'id': 'str'})
df.head()
# Out:
#         id
# 0  4104757
# 1  0801306
# 2  3609931

# %% [markdown]
# # Using .apply to save mine data for SEVERAL mines
#
# The file `mines-subset.csv` has a list of mine IDs. We're going to scrape the operator's name for each of those mines.
#
# ### Open up `mines-subset.csv` and save it into a dataframe

# %%
df = pd.read_csv("mines-subset.csv", dtype={'id': 'str'})
df.head()
# Out:
#         id
# 0  4104757
# 1  0801306
# 2  3609931

# %% [markdown]
# ### Scrape the violations for each mine
#
# **Save each mine's violations into separate CSV files.** Each CSV file must include the following fields:
#
# - Citation number
# - Case number
# - Standard violated
# - Link to standard
# - Proposed penalty
# - Amount paid to date
#
# Make sure you are saving them into **separate files.** It might be nice to name them after the mine id.
#
# - *TIP: Use .apply for this*
# - *TIP: Print out the ID before you start scraping. That way you can take that ID and search manually to see if there is anything weird about the results.*
# - *TIP: If you need help with .apply, look at the "Using apply in pandas" notebook
# - *TIP: It's probably worth it to print the fields first, then save them to a CSV once you know it's all working.*

# %%
def scrape_violations(row):
    print(row['id'])
    
    driver.get("https://arlweb.msha.gov/drs/drshome.htm")
    input_field = driver.find_element_by_name("MineId")
    input_field.send_keys(row['id'])
    search_button = driver.find_element_by_xpath('//*[@id="content"]/table[3]/tbody/tr[3]/td[2]/input')
    search_button.click()
    
    
    # search for violations
    date_field = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[2]/tbody/tr[2]/td/font/input[1]')
    date_field.send_keys("1/1/1995")
    
    violation_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[2]/td[2]/table/tbody/tr[1]/td/input')
    violation_button.click()
    
    reports_button = driver.find_element_by_xpath('//*[@id="content"]/form[1]/table[3]/tbody/tr[3]/td[2]/input')
    reports_button.click()
    
    doc = BeautifulSoup(driver.page_source, 'html.parser')
    violation_rows = doc.find_all('tr', class_='drsviols')
    
    violations = []
    for violation_row in violation_rows:
        violation = {}
        cells = violation_row.find_all('td')
        violation['citation'] = cells[2].text.strip()
        violation['case no'] = cells[3].text.strip()
        a_tag = cells[10].find('a')
        if a_tag:
            violation['standard'] = a_tag.text.strip()
            violation['link'] = a_tag['href']
        if len(cells) > 14:
            violation['proposed'] = cells[11].text.strip()
            violation['paid'] = cells[14].text.strip()
        violations.append(violation)
            
    violations_df = pd.DataFrame(violations)
    violations_df.to_csv(row['id'] + "-violations.csv", index=False)
    

df.apply(scrape_violations, axis=1)
# Out:
# 4104757
# 0801306
# 3609931
# 0    None
# 1    None
# 2    None
# dtype: object

# %%
doc = BeautifulSoup(driver.page_source, 'html.parser')
violation_rows = doc.find_all('tr', class_='drsviols')
    
violations = []
for violation_row in violation_rows:
    violation = {}
    cells = violation_row.find_all('td')
    violation['citation'] = cells[2].text.strip()
    violation['case no'] = cells[3].text.strip()
    a_tag = cells[10].find('a')
    if a_tag:
        violation['standard'] = a_tag.text.strip()
        violation['link'] = a_tag['href']
    if len(cells) > 14:
        violation['proposed'] = cells[11].text.strip()
        violation['paid'] = cells[14].text.strip()
    violations.append(violation)

# %%
pd.DataFrame(violations)
# Out:
#          case no citation                                               link  \
# 0                 8912694  http://www.ecfr.gov/cgi-bin/text-idx?SID=f462b...
# 1      000427623  8638781  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 2      000411633  8903432  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 3      000411633  8903433  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 4      000411633  8903434  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 5      000411633  8903435  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 6      000411633  8903436  http://www.gpo.gov/fdsys/pkg/CFR-2016-title30-...
# 7      000397972  8822977  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 8      000397972  8822975  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 9      000397972  8822973  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 10     000397972  8822976  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 11     000397972  8822974  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 12     000382609  8818270  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 13     000382609  8818269  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 14     000375494  8818247  http://www.gpo.gov/fdsys/pkg/CFR-2015-title30-...
# 15     000360091  8835756  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...
# 16     000360091  8835757  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...
# 17     000346593  8732850  http://www.gpo.gov/fdsys/pkg/CFR-2014-title30-...
# 18     000334543  8729316  http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-...
# 19     000334543  8729317  http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-...
# 20     000315004  8723395  http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-...
# 21     000315004  8723396  http://www.gpo.gov/fdsys/pkg/CFR-2013-title30-...
# 22     000296474  8638087  http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-...
# 23     000293592  8638086  http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-...
# 24     000293592  8638085  http://www.gpo.gov/fdsys/pkg/CFR-2012-title30-...
# 25     000273703  8637959  http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-...
# 26     000256650  8630131  http://www.gpo.gov/fdsys/pkg/CFR-2011-title30-...
# 27     000230512  8547870  http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-...
# 28     000230512  8547867  http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-...
# 29     000230512  8547868  http://www.gpo.gov/fdsys/pkg/CFR-2010-title30-...
# ..           ...      ...                                                ...
# 46     000089619  6110212  http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-...
# 47     000089619  6110214  http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-...
# 48     000089619  6110217  http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-...
# 49     000089619  6110216  http://www.gpo.gov/fdsys/pkg/CFR-2006-title30-...
# 50     000063118  6088757  http://www.gpo.gov/fdsys/pkg/CFR-2005-title30-...
# 51     000058196  6094158  http://www.gpo.gov/fdsys/pkg/CFR-2005-title30-...
# 52     000058196  6094157  http://www.gpo.gov/fdsys/pkg/CFR-2005-title30-...
# 53     000058196  6094156  http://www.gpo.gov/fdsys/pkg/CFR-2005-title30-...
# 54     000058196  6094159  http://www.gpo.gov/fdsys/pkg/CFR-2005-title30-...
# 55     000041636  6093408  http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-...
# 56     000041636  6093407  http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-...
# 57     000041636  6093409  http://www.gpo.gov/fdsys/pkg/CFR-2004-title30-...
# 58  080130605503  6092154  http://www.gpo.gov/fdsys/pkg/CFR-2003-title30-...
# 59  080130605503  6092152  http://www.gpo.gov/fdsys/pkg/CFR-2003-title30-...
# 60  080130605503  6092153  http://www.gpo.gov/fdsys/pkg/CFR-2003-title30-...
# 61  080130605503  6092151  http://www.gpo.gov/fdsys/pkg/CFR-2003-title30-...
# 62  080130605502  7763977  http://www.gpo.gov/fdsys/pkg/CFR-2002-title30-...
# 63  080130605502  7763978  http://www.gpo.gov/fdsys/pkg/CFR-2002-title30-...
# 64  080130605502  7763975  http://www.gpo.gov/fdsys/pkg/CFR-2002-title30-...
# 65  080130605502  7763979  http://www.gpo.gov/fdsys/pkg/CFR-2002-title30-...
# 66  080130605502  7763976  http://www.gpo.gov/fdsys/pkg/CFR-2002-title30-...
# 67  080130605501  7764984  http://www.gpo.gov/fdsys/pkg/CFR-2002-title30-...
# 68  080130605501  7764907  http://www.gpo.gov/fdsys/pkg/CFR-2001-title30-...
# 69  080130605501  7764904  http://www.gpo.gov/fdsys/pkg/CFR-2001-title30-...
# 70  080130605501  7764901  http://www.gpo.gov/fdsys/pkg/CFR-2001-title30-...
# 71  080130605501  7764905  http://www.gpo.gov/fdsys/pkg/CFR-2001-title30-...
# 72  080130605501  7764903  http://www.gpo.gov/fdsys/pkg/CFR-2001-title30-...
# 73  080130605501  7764906                                                NaN
# 74  080130605501  7764908  http://www.gpo.gov/fdsys/pkg/CFR-2001-title30-...
# 75  080130605501  7764902  http://www.gpo.gov/fdsys/pkg/CFR-2001-title30-...
#
#       paid proposed           standard
# 0      NaN      NaN        56.14132(a)
# 1   351.00   351.00           56.12028
# 2   100.00   100.00           47.41(a)
# 3   100.00   100.00        56.14100(b)
# 4   117.00   117.00           46.11(d)
# 5   117.00   117.00         56.9300(a)
# 6   100.00   100.00           56.12004
# 7   100.00   100.00         56.9300(b)
# 8   100.00   100.00        56.14100(c)
# 9   100.00   100.00         56.9300(a)
# 10  100.00   100.00     56.14101(a)(2)
# 11  100.00   100.00        56.14100(b)
# 12  100.00   100.00           56.12040
# 13  100.00   100.00        56.14211(b)
# 14  100.00   100.00           56.12004
# 15  100.00   100.00           50.30(a)
# 16  100.00   100.00        56.14100(b)
# 17  100.00   100.00        56.14100(a)
# 18  117.00   117.00         56.9300(a)
# 19  100.00   100.00        56.18002(b)
# 20  100.00   100.00        56.14107(a)
# 21  100.00   100.00           56.11003
# 22  100.00   100.00         56.9100(a)
# 23  100.00   100.00        56.14132(a)
# 24  807.00   807.00        56.14100(b)
# 25  100.00   100.00            46.9(a)
# 26  100.00   100.00           56.12032
# 27  100.00   100.00           56.12028
# 28  100.00   100.00           56.18010
# 29  100.00   100.00            46.9(a)
# ..     ...      ...                ...
# 46   60.00    60.00           56.16006
# 47  614.00   614.00        56.12013(b)
# 48   60.00    60.00           56.12004
# 49   60.00    60.00           47.41(a)
# 50   60.00    60.00              50.30
# 51   60.00    60.00        56.14132(a)
# 52   60.00    60.00            56.4102
# 53   60.00    60.00      56.4200(a)(1)
# 54   60.00    60.00        56.20003(a)
# 55   60.00    60.00        56.14132(a)
# 56  268.00   268.00           56.12016
# 57   60.00    60.00      46.9(c)(2)(i)
# 58   60.00    60.00        56.20003(a)
# 59   60.00    60.00         56.9300(a)
# 60  106.00   106.00     56.14103(c)(1)
# 61  133.00   133.00            56.4402
# 62  104.00   104.00  56.14132(b)(1)(i)
# 63   55.00    55.00      56.4230(a)(1)
# 64   55.00    55.00        56.20003(a)
# 65   55.00    55.00           56.16006
# 66  104.00   104.00        56.14100(b)
# 67   55.00    55.00          62.130(a)
# 68  113.00   113.00        56.14130(g)
# 69   55.00    55.00           56.12028
# 70   55.00    55.00        56.14107(a)
# 71   55.00    55.00            56.1000
# 72   55.00    55.00           56.18010
# 73     NaN      NaN                NaN
# 74  113.00   113.00           56.12013
# 75   55.00    55.00           56.12004
#
# [76 rows x 6 columns]
