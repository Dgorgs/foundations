# %% [markdown]
# # Number One: Mapping Basics (Mapping NYC Art Galleries)
#
# You have two datasets:
#
# * A shapefile of New York City neighborhoods, unzipped into `nynta_14d/`
# * A csv of art galleries in New York City, called `galleries.csv`
#
# We're going to create a visualization by plotting points for each art gallery on top of a map of neighborhoods.

# %% [markdown]
# ## Part Zero: Importing what you need
#
# Probably pandas, geopandas, a bit of matplotlib magic to make your graphics show up in the notebook, maybe some other stuff..

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
# %matplotlib inline

# %% [markdown]
# ## Part One: Opening your datasets
#
# **Open up both files!**
#
# You want to end up with two **GeoDataFrames**, which are exactly like dataframes except they, of course, have some geography associated with them - a.k.a. `geometry`. Geopandas works nicely with shapefiles **but** when you're dealing with the csv there's a little extra work involved.
#
# **MAKE SURE YOU SET THE GALLERY CRS TO `{'init': 'epsg:4326'}` - the [world geodetic system](https://en.wikipedia.org/wiki/World_Geodetic_System).** The geopandas website wants you to use a different one - `3395` - but I promise it doesn't really work.

# %%
neighborhood = gpd.read_file("/Users/daniela/Desktop/Ledeprogram/Foundation_Soma/13-homework/nynta_14d/nynta.shp")

# %%
neighborhood.head()
# Out:
#    BoroCode  BoroName CountyFIPS NTACode               NTAName    Shape_Area  \
# 0         3  Brooklyn        047    BK43               Midwood  3.579964e+07
# 1         3  Brooklyn        047    BK75               Bedford  3.262983e+07
# 2         2     Bronx        005    BX40         Fordham South  6.307284e+06
# 3         3  Brooklyn        047    BK88          Borough Park  5.400502e+07
# 4         3  Brooklyn        047    BK96  Rugby-Remsen Village  3.270695e+07
#
#      Shape_Leng                                           geometry
# 0  27996.591274  POLYGON ((998870.8071899414 168503.1193847656,...
# 1  29992.919174  POLYGON ((1000351.30279541 194574.900390625, 9...
# 2  15878.272921  POLYGON ((1014295.119384766 253236.9890136719,...
# 3  39247.227722  POLYGON ((990897.9002075195 169268.1207885742,...
# 4  30957.853395  POLYGON ((1009623.354003906 176865.7595825195,...

# %%
df = pd.read_csv("galleries.csv")
df
# Out:
#                                                   name              tel  \
# 0                            O'reilly William & Co Ltd   (212) 396-1822
# 1    Organization of Independent Artists - Gallery 402   (212) 219-9213
# 2                                         Owen Gallery   (212) 879-2415
# 3                                     P P O W Gallerie   (212) 647-1044
# 4                                          P P O W Inc   (212) 941-8642
# 5                                      P S 122 Gallery   (212) 228-4249
# 6                                        Pace Editions   (212) 645-9806
# 7                                 Pace MacGill Gallery   (212) 759-7999
# 8                      Pace Prints & Primitive Gallery   (212) 421-3237
# 9                                     Pace Wildenstein   (212) 929-7000
# 10                                    Pace Wildenstein   (212) 421-3292
# 11                                 Paige's Art Gallery   (212) 531-1577
# 12                                 PaineWebber Gallery   (212) 713-2885
# 13                                   Paint Can Studios   (718) 937-7360
# 14                                     Paley Barbara K   (212) 333-4747
# 15                                    Pall William Inc   (212) 758-3340
# 16                             Palmer Meredith Gallery   (212) 828-9100
# 17                                 Pandora Old Masters   (212) 628-1974
# 18                         Pardo Sheenan Galleries Ltd   (646) 935-0837
# 19                                        Parker's Box   (718) 388-2882
# 20                                   Parsons Galleries   (212) 229-8987
# 21                       Patricia Laligant Photographs   (212) 252-9922
# 22                                   Patrick's Gallery   (212) 741-7453
# 23                                 Paul Kasmin Gallery   (212) 563-4474
# 24                                Paula Cooper Gallery   (212) 255-1105
# 25                         Peck Ian Fine Paintings Ltd   (212) 396-2442
# 26                                   Peder Bonnier Inc   (646) 638-0878
# 27                                   Perimeter Gallery   (212) 675-1585
# 28                   Perlow Rich Katharina Gallery Inc   (212) 644-7171
# 29                              Peter L Villa Fine Art   (212) 371-1196
# ..                                                 ...              ...
# 887                              Morgan Art Consulting   (212) 447-0490
# 888                           Morning Star Gallery Ltd   (212) 334-9330
# 889                  Naegele Amyas Bases & African Art   (212) 465-0524
# 890                                Naiman Lee Fine Art   (212) 362-4090
# 891                          Nancy Hoffman Gallery Inc   (212) 966-6676
# 892                         Nancy Margolis Gallery Inc   (212) 242-3013
# 893                                   Natalie Karg Ltd   (212) 563-7821
# 894                                Nathaniel Moore Llc   (212) 965-9500
# 895                                     Navarra Enrico   (212) 223-2828
# 896                             Neal Meltzer Fine Arts   (212) 829-9800
# 897                        Neikrug Marjorie Appraisals   (212) 688-8779
# 898                                Neuhoff Gallery Inc  (212)  838-1122
# 899                      New Dorp Village Antiques Ltd   (718) 815-2526
# 900                              New York Art Expo Inc   (212) 363-8280
# 901                               New York Art Gallery   (212) 396-0275
# 902                             New York Gallery Tours   (212) 946-1548
# 903                                  Nexus Gallery Inc   (212) 982-4712
# 904                                Nohra Haime Gallery   (212) 888-3550
# 905                               Nolan Eckman Gallery   (212) 925-6190
# 906                  Northstar Research Associates Inc   (212) 721-7000
# 907                       Nyabinghi Africian Gift Shop   (212) 566-3336
# 908                                    O J Art Gallery   (212) 420-0417
# 909                                O.K. Harris Gallery   (212) 431-3600
# 910                                       Object-Image   (718) 623-2434
# 911                                          Oditi Inc   (212) 427-5885
# 912                                    Odyssia Gallery   (212) 486-7338
# 913                                 Old Print Shop Inc   (212) 683-3950
# 914                            Omniguard Art Guarantee   (212) 577-9000
# 915                                   One Twenty Eight   (212) 674-0244
# 916                                      Opera Gallery   (212) 966-6675
#
#                                                    url  \
# 0    http://www.nyc.com/arts__attractions/oreilly_w...
# 1    http://www.nonprofitgallery.com/main/usa/ny/oi...
# 2                  http://www.owengallery.com/about-us
# 3                          http://www.ppowgallery.com/
# 4    http://www.nyc.com/arts__attractions/p_p_o_w_i...
# 5                             http://ps122gallery.org/
# 6    http://www.ziplocal.com/companies/103327232-Pa...
# 7          http://www.pacemacgill.com/exhibitions.html
# 8                           http://www.paceprints.com/
# 9                      http://www.pacewildenstein.com/
# 10   http://www.pacewildenstein.com/uploads/exhibit...
# 11   http://www.nyc.com/arts__attractions/paiges_ar...
# 12              http://www.tfaoi.com/aa/1aa/1aa458.htm
# 13   http://ny.serviceslisted.com/1655944-PaintCanS...
# 14   http://www.nyc.com/arts__attractions/paley_bar...
# 15   http://local.botw.org/New_York/New_York/Pall_W...
# 16   http://www.artinfo.com/galleryguide/12649/1149...
# 17      http://www.salondudessin.com/an/anpandora.html
# 18   http://web2.userinstinct.com/30816848-pardo-sh...
# 19   http://www.parkersbox.com/exhibitions/current/...
# 20                         http://www.parsonswest.com/
# 21           http://www.patricialaligant.com/intro.htm
# 22   http://outalot.com/listings/318942-Patricks-Ga...
# 23                   http://www.paulkasmingallery.com/
# 24                  http://www.paulacoopergallery.com/
# 25   http://gallerydriver.com/?method=Gallery.Galle...
# 26   http://web2.userinstinct.com/30816857-peder-bo...
# 27   http://www.spoke.com/info/c633Fr3/PerimeterGal...
# 28      http://www.artnet.com/katharinarichperlow.html
# 29                      http://peterlvillafineart.com/
# ..                                                 ...
# 887                    http://morganartconsulting.com/
# 888  http://www.nyc.com/arts__attractions/morning_s...
# 889  http://www.merchantcircle.com/business/Naegele...
# 890  http://www.nyc.com/arts__attractions/naiman_le...
# 891                http://www.nancyhoffmangallery.com/
# 892                   http://nancymargolisgallery.com/
# 893  http://www.masterseek.com/id/7052478/Natalie-K...
# 894  http://www.zipleaf.us/Companies/Nathaniel-Moor...
# 895           http://www.enriconavarra.com/flash6.html
# 896                        http://www.nealmeltzer.com/
# 897  http://newyorkny.zemantics.com/business/neikru...
# 898                     http://www.neuhoffgallery.com/
# 899  http://businessfinder.silive.com/2321461/New-D...
# 900  http://www.merchantcircle.com/business/New.Yor...
# 901  http://hellonewyorkcity.com/Business_Profile/1...
# 902                     http://www.nygallerytours.com/
# 903  http://www.nyc.com/arts__attractions/nexus_gal...
# 904                  http://www.artnet.com/nhaime.html
# 905  http://ny.serviceslisted.com/1655106-NolanEckm...
# 906  http://goliath.ecnext.com/coms2/product-compin...
# 907  http://www.nyc.com/arts__attractions/nyabinghi...
# 908      http://www.manta.com/coms2/dnbcompany_ccv29cr
# 909                           http://www.okharris.com/
# 910  http://www.laurafantini.it/Documents/For_Immed...
# 911  http://www.ibegin.com/directory/us/new-york/ne...
# 912  http://www.livevillage.com/newyork/art/odyssia...
# 913                       http://www.oldprintshop.com/
# 914  http://www.city-data.com/businesses/683951099-...
# 915              http://www.galleryonetwentyeight.org/
# 916                http://www.popaganda.com/events.htm
#
#                        addr1    addr2           city    zip  longitude  \
# 0               52 E 76th St      NaN       New York  10021 -73.962731
# 1              19 Hudson St.      NaN       New York  10013 -74.009386
# 2               19 E 75th St      NaN       New York  10021 -73.964352
# 3              511 W 25th St      NaN       New York  10001 -74.003893
# 4              476 Broome St      NaN       New York  10013 -74.001764
# 5                150 1st Ave      NaN       New York  10009 -73.984371
# 6               44 W 18th St      NaN       New York  10011 -73.994377
# 7             32 E. 57th St.  9th Fl.       New York  10022 -73.972022
# 8             32 E. 57th St.  3rd Fl.       New York  10022 -73.972115
# 9              534 W 25th St      NaN       New York  10001 -74.004951
# 10              32 E 57th St     Fl 4       New York  10022 -73.972077
# 11             3163 Broadway      NaN       New York  10027 -73.959274
# 12           1285 Sixth Ave.      NaN       New York  10019 -73.980584
# 13              3608 34th St      NaN        Astoria  11106 -73.927940
# 14             1776 Broadway      NaN       New York  10019 -73.981480
# 15             188 E 64th St      NaN       New York  10021 -73.964812
# 16              40 E 94th St      NaN       New York  10128 -73.954822
# 17             212 E 70th St      NaN       New York  10021 -73.960816
# 18             121 E 31st St      NaN       New York  10016 -73.981561
# 19              193 Grand St      NaN       Brooklyn  11211 -73.960445
# 20             2 W. 13th St.      NaN       New York  10011 -73.994782
# 21             150 W 28th St      NaN       New York  10001 -73.992821
# 22             220 W 19th St      NaN       New York  10011 -73.998510
# 23              293 10th Ave      NaN       New York  10001 -74.002723
# 24           534 W. 21st St.      NaN       New York  10011 -74.006898
# 25           980 Madison Ave      NaN       New York  10021 -73.963650
# 26             206 W 23rd St     Fl 4       New York  10011 -73.996239
# 27             511 W 25th St      NaN       New York  10001 -74.003899
# 28              41 E 57th St      NaN       New York  10022 -73.971640
# 29             110 E 57th St      NaN       New York  10022 -73.970294
# ..                       ...      ...            ...    ...        ...
# 887    303 Park Avenue South    #1204       New York  10010 -73.985780
# 888             9809 64th Rd      NaN      Rego Park  11374 -73.857833
# 889            347 W 36th St      NaN       New York  10018 -73.994336
# 890       300 Central Park W      NaN       New York  10024 -73.967674
# 891           429 W Broadway      NaN       New York  10012 -74.001024
# 892        523 W 25th Street      NaN       New York  10001 -74.004184
# 893            325 W 38th St      NaN       New York  10018 -73.992666
# 894            121 Hudson St      NaN       New York  10013 -74.008864
# 895             41 E 57th St      NaN       New York  10022 -73.972000
# 896          600 Madison Ave      NaN       New York  10022 -73.972420
# 897            136 E 64th St      NaN       New York  10021 -73.966260
# 898             41 E 57th St      NaN       New York  10022 -73.972058
# 899             517 Broadway      NaN  Staten Island  10310 -74.115818
# 900             3 Hanover Sq      NaN       New York  10004 -74.009608
# 901             1626 1st Ave      NaN       New York  10028 -73.949753
# 902            82 Charles St      NaN       New York  10014 -74.003944
# 903            345 E 12th St      NaN       New York  10003 -73.983945
# 904      41 East 57th Street      NaN       New York  10022 -73.972104
# 905             560 Broadway      NaN       New York  10012 -73.997740
# 906            215 W 88th St   Apt 8D       New York  10024 -73.974844
# 907          111 Chambers St      NaN       New York  10007 -74.008153
# 908  446 Ave of the Americas      NaN       New York  10011 -73.998290
# 909          383 W. Broadway      NaN       New York  10012 -74.002071
# 910               91 5th Ave      NaN       Brooklyn  11217 -73.977898
# 911       1500 Lexington Ave      NaN       New York  10029 -73.950850
# 912            305 E 61st St      NaN       New York  10021 -73.962698
# 913        150 Lexington Ave      NaN       New York  10016 -73.981948
# 914             115 Broadway      NaN       New York  10006 -74.011472
# 915         128 Rivington St      NaN       New York  10002 -73.986913
# 916            115 Spring St      NaN       New York  10012 -73.999948
#
#       latitude
# 0    40.773801
# 1    40.716469
# 2    40.774001
# 3    40.749585
# 4    40.722907
# 5    40.728168
# 6    40.739202
# 7    40.761950
# 8    40.761836
# 9    40.749448
# 10   40.761886
# 11   40.815001
# 12   40.761189
# 13   40.755158
# 14   40.766370
# 15   40.764509
# 16   40.785633
# 17   40.767892
# 18   40.744896
# 19   40.714309
# 20   40.735395
# 21   40.746760
# 22   40.741869
# 23   40.750193
# 24   40.746920
# 25   40.774761
# 26   40.744060
# 27   40.749381
# 28   40.762365
# 29   40.761170
# ..         ...
# 887  40.740254
# 888  40.729925
# 889  40.754486
# 890  40.788344
# 891  40.725180
# 892  40.749647
# 893  40.755338
# 894  40.720311
# 895  40.762503
# 896  40.762940
# 897  40.765369
# 898  40.762433
# 899  40.628433
# 900  40.705000
# 901  40.775828
# 902  40.734595
# 903  40.730425
# 904  40.762370
# 905  40.723978
# 906  40.789563
# 907  40.715235
# 908  40.734888
# 909  40.723689
# 910  40.679849
# 911  40.786365
# 912  40.761875
# 913  40.743673
# 914  40.708939
# 915  40.719807
# 916  40.723815
#
# [917 rows x 9 columns]

# %% [markdown]
# ## Part Two: Making some maps
#
# ### Part Two, Section A: Mapping individually
#
# Make a map of neighborhoods, and a map of galleries. Make sure the shape of Manhattan kind of **looks kind of like Google Maps**. If not you need to change your crs/projection!
#
# **For the neighborhoods map,** make each shape a light grey color, and the boundary lines between the neighborhoods white. It's relaxing and good for adding more things to!
#
# **For the galleries map,** make them all the same color. I don't care what color it is, just make it a liiiitle transparent so you can maybe kind of tell if galleries are close to one another.

# %%
neighborhood.plot(color='lightgrey', linewidth=0.25, edgecolor='white')

# %%
points = df.apply(lambda row: Point(row.longitude, row.latitude), axis=1)
galleries = gpd.GeoDataFrame(df, geometry=points)
galleries.crs = {'init': 'epsg:4326'}
galleries.plot()

# %% [markdown]
# ## Part Two, Section B: Map them on top of each other
#
# Now make the map a *lot* bigger and plot the galleries on top of the neighborhoods.
#
# And just so you know: you can't do it the easy way, it just won't work. I'm looking for a terrible failure here, not success.

# %%
ax = neighborhood.plot(color='lightgrey', linewidth=0.25, edgecolor='white')
galleries.plot(ax=ax, color='pink', markeredgewidth=0, markersize=3)
ax.axis('off')
# Out:
# (-53446.982610037354,
#  1120755.3415210044,
#  -13599.589678872109,
#  286484.47875191428)

# %% [markdown]
# Notice how the map is in the top right, and there's a little green in the bottom left? **That's a CRS problem.** Let's fix it.
#
# ### Let's fix any coordinate reference system (CRS) problems
#
# The CRS is the coordinate system that's used to represent the globe, especially on a flat surface. Before you plot data, you need to make sure they're in the same CRS. If not, you wind up with problems like the above and you won't be able to put your datasets on the same map (or spatially join them, to boot).
#
# **What's the CRS of the galleries?** Find out by running `galleries.crs`.

# %%
galleries.crs
# Out:
# {'init': 'epsg:4326'}

# %% [markdown]
# Yeah, we set that when we imported it. **What about the neighborhoods?** Is it the same CRS? Just do `.crs` on the neighborhoods geodataframe.

# %%
neighborhood.crs
# Out:
# {'datum': 'NAD83',
#  'lat_0': 40.16666666666666,
#  'lat_1': 40.66666666666666,
#  'lat_2': 41.03333333333333,
#  'lon_0': -74,
#  'no_defs': True,
#  'proj': 'lcc',
#  'units': 'us-ft',
#  'x_0': 300000,
#  'y_0': 0}

# %% [markdown]
# Hot damn, who even knows what that nonsense means! Well, I do, and technically speaking it's the [New York State Plane System](https://en.wikipedia.org/wiki/State_Plane_Coordinate_System). A lot of state- and city-level data will be state plane, and you aaalways need to convert it. It uses a potato shape and datum that's great for New York and not so great for places further away from New York.
#
# And just as a reminder of how different the projects of the neighborhoods and galleries are, let's plot them both.

# %%
neighborhood.plot()
galleries.plot()

# %% [markdown]
# **Notice how the neighborhoods axes are in the thousands, while ones for the galleries look like normal lat/long!** As a result, mapping them on the same map will never work.
#
# For the New York State Plane System, basically what the government did was say "Screw latitude and longitude, let's put 0,0 at some point in New Jersey, and measure everything starting from there." So the big numbers on the NYC scale are *meters from some place in Jersey*.
#
# **Okay, now let's convert the neighborhoods dataset to use the same CRS as the galleries dataset.**

# %%
neighborhood.plot() #old epsg

# %%
neighborhood.to_crs(epsg=4326).plot()

# %%
#neighborhoods = neighborhoods.to_crs(galleries_geo.crs)

# %% [markdown]
#  See how the `geometry` now looks like latitude and longitude? Beautiful.
#
# ### Map the converted neighborhoods dataset with the galleries dataset
#
# Everything should be good to go now. Make it look nice - enlarge it a bit, turn off the axes, make the neighborhoods pleasant and grey with white lines, and gentle up the gallery dots.
#
# *And make sure you make the projection look like Google Maps!* It's the worst projection but hey it's fine for now! You can try `aea` if you wanna get crazy.

# %%
ax = neighborhood.to_crs(epsg=4326).plot(figsize=(20,20), color='#BBBBBB', linewidth=0.25, edgecolor='white')
galleries.plot(ax=ax, color='red', markeredgewidth=0, markersize=4)
ax.axis('off')
# Out:
# (-74.283370478149223,
#  -73.672229948213371,
#  40.47514452610185,
#  40.936503645568806)
